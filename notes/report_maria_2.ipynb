# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Visualización
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluar linealidad de las relaciones entre las variables
# y la distribución de las variables
# ------------------------------------------------------------------------------
import scipy.stats as stats
from scipy.stats import ttest_ind, norm, chi2_contingency, f_oneway, shapiro, kstest
from sklearn.linear_model import LinearRegression

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# Gestión de los warnings
# -----------------------------------------------------------------------
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('data-hotel-clean.csv', index_col=0)

df.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 63882     City Hotel         True        346                         8
# 18507   Resort Hotel        False         36                        47
# 1636    Resort Hotel        False        128                        28
# 111314    City Hotel        False        144                        18
# 31364   Resort Hotel        False        124                        52
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 63882                         0                     2       2         0
# 18507                         0                     2       1         0
# 1636                          2                     5      51         0
# 111314                        2                     1       2         0
# 31364                         1                     2       2         0
#
#         babies meal    country market_segment distribution_channel  \
# 63882        0   BB  Undefined      Online TA                TA/TO
# 18507        0   FB      Spain         Groups                TA/TO
# 1636         0   BB    Ireland      Undefined                TA/TO
# 111314       0   BB  Undefined      Undefined                TA/TO
# 31364        0   BB      Spain      Online TA                TA/TO
#
#         is_repeated_guest  previous_cancellations  \
# 63882               False                       0
# 18507               False                       0
# 1636                False                       0
# 111314              False                       0
# 31364               False                       0
#
#         previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 63882                                0                  A                  A
# 18507                                0                  A                  A
# 1636                                 0                  E                  E
# 111314                               0                  A                  A
# 31364                                0                  A                  A
#
#         booking_changes  agent  days_in_waiting_list    customer_type    adr  \
# 63882                 0    9.0                     0        Transient  81.90
# 18507                 0   38.0                     0        Undefined   0.00
# 1636                  0   95.0                     0        Undefined  97.50
# 111314                2   52.0                     0  Transient-Party  90.00
# 31364                 0  240.0                     0  Transient-Party  51.13
#
#         required_car_parking_spaces  total_of_special_requests  \
# 63882                             0                          0
# 18507                             0                          0
# 1636                              0                          0
# 111314                            0                          0
# 31364                             0                          3
#
#        reservation_status reservation_status_date  courtesy arrival_date
# 63882            Canceled              2016-08-01     False   2016-02-24
# 18507           Check-Out              2015-11-22      True   2015-11-20
# 1636            Check-Out              2015-09-13     False   2015-09-06
# 111314          Check-Out              2017-09-05     False   2017-05-06
# 31364           Check-Out              2016-12-26     False   2016-12-23

# %%
df['arrival_date'] =df['arrival_date'].str.replace('2016-2-31', '2016-2-28')
df['arrival_date'] =df['arrival_date'].str.replace('2015-2-29', '2015-2-28')

# %%
filas_conteniendo_31 = df[df["reservation_status_date"].str.contains('31', na=False)]
valores_unicos = filas_conteniendo_31["reservation_status_date"].unique()


df['reservation_status_date'] = df['reservation_status_date'].str.replace(r'31$', '28', regex=True)
df['reservation_status_date'] = df['reservation_status_date'].str.replace(r'30$', '28', regex=True)

# %%
formato_fecha = "%Y-%m-%d"

try:
    df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format=formato_fecha)
except ValueError as e:
    # Si ocurre un error al convertir la fecha, imprime el mensaje de error
    print("Error al convertir la fecha:", e)

# %%
df['arrival_date'] = pd.to_datetime(df['arrival_date'])

# %% [markdown]
# ### Objeto análisis
#
# - Por qué han aumentado las cancelaciones?

# %% [markdown]
# 1. Analizar cuanto respresentas las cancelaciones del total

# %% [markdown]
# Indica si la reserva fue cancelada (True) o no (False)

# %%
cancelaciones = df["is_canceled"].value_counts()

etiquetas = ["No Cancelado", "Cancelado"]

plt.figure(figsize=(20, 6))
plt.pie(cancelaciones.values, 
        labels=etiquetas, 
        autopct='%1.1f%%', 
        colors=["#6930c3", "#5e60ce"],
        startangle=140, textprops={'color':"white"})
plt.axis('equal')
plt.title('Distribución de las cancelaciones', fontsize = 16, fontweight = "bold", color="white" );

# %% [markdown]
# Se cancelan un 37,1% de las reservas

# %%
# Primer conjunto de datos basado en la fecha de status de reserva
cancelada_status = df[df["is_canceled"] == True] .groupby([df["reservation_status_date"].dt.year, df["reservation_status_date"].dt.month])["is_canceled"].count()
no_cancelada_status = df[df["is_canceled"] == False].groupby([df["reservation_status_date"].dt.year, df["reservation_status_date"].dt.month])["is_canceled"].count()

etiquetas_x_status = [f'{año}-{mes}' for año, mes in cancelada_status.index]
posiciones_x_status = list(range(len(etiquetas_x_status)))

plt.figure(figsize=(20, 6))

# Trazar la línea para is_canceled == True (status de reserva)
cancelada_status.plot(kind='line', marker='o', linestyle='-', color='red', linewidth=3, label='Canceladas')
# Trazar la línea para is_canceled == False (status de reserva)
no_cancelada_status.plot(kind='line', marker='s', linestyle='-', color='green', linewidth=3, label='No canceladas')

plt.title('Evolución de las reservas por Año-mes por fecha de status de la reserva')
plt.xlabel('Año-Mes')
plt.ylabel('Número de reservas')

plt.xticks(posiciones_x_status, etiquetas_x_status, color="blue", fontsize=10, rotation=45)

plt.legend()

# Segundo conjunto de datos basado en la fecha de llegada
cancelada_llegada = df[df["is_canceled"] == True].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()
no_cancelada_llegada = df[df["is_canceled"] == False].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()

etiquetas_x_llegada = [f'{año}-{mes}' for año, mes in cancelada_llegada.index]
posiciones_x_llegada = list(range(len(etiquetas_x_llegada)))

plt.figure(figsize=(20, 6))

# Trazar la línea para is_canceled == True (fecha de llegada)
cancelada_llegada.plot(kind='line', marker='o', linestyle='-', color='red', linewidth=3, label='Canceladas')
# Trazar la línea para is_canceled == False (fecha de llegada)
no_cancelada_llegada.plot(kind='line', marker='s', linestyle='-', color='green', linewidth=3, label='No canceladas')

plt.title('Evolución de las reservas por Año-mes por fecha de llegada')
plt.xlabel('Año-Mes')
plt.ylabel('Número de reservas')

plt.xticks(posiciones_x_llegada, etiquetas_x_llegada, color="blue", fontsize=10, rotation=45)

plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# En Abril de 2016, por fecha de llegada, se igualan las reservas canceladas a las no canceladas.
# En Diciembre de 2016 vuelve a ocurrir estoy después de esa fecha, son más las cancelaciones que las reservas en el hotel.

# %%
df.sample(5)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_week_number  \
# 32015   Resort Hotel        False          4                         2
# 79591     City Hotel        False          7                        44
# 118344    City Hotel        False         69                        28
# 71919     City Hotel         True        476                        28
# 94677     City Hotel        False        137                        31
#
#         stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 32015                         0                     1      50         0
# 79591                         0                     1       1         0
# 118344                        2                     4       2         0
# 71919                         2                     1       2         0
# 94677                         3                     7       2         0
#
#         babies meal    country market_segment distribution_channel  \
# 32015        0   HB   Portugal      Undefined                TA/TO
# 79591        0   BB  Undefined         Direct            Undefined
# 118344       0   SC     Brazil      Undefined                TA/TO
# 71919        0   BB   Portugal  Offline TA/TO                TA/TO
# 94677        0   HB  Undefined      Online TA                TA/TO
#
#         is_repeated_guest  previous_cancellations  \
# 32015               False                       0
# 79591               False                       0
# 118344              False                       0
# 71919               False                       0
# 94677               False                       0
#
#         previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 32015                                0                  A                  A
# 79591                                0                  A                  A
# 118344                               0                  A                  A
# 71919                                0          Undefined                  A
# 94677                                0                  D                  D
#
#         booking_changes      agent  days_in_waiting_list    customer_type  \
# 32015                 0      168.0                     0        Undefined
# 79591                 0  Undefined                     0  Transient-Party
# 118344                0        9.0                     0        Transient
# 71919                 0      229.0                     0  Transient-Party
# 94677                 0        9.0                     0        Transient
#
#            adr  required_car_parking_spaces  total_of_special_requests  \
# 32015    68.00                            0                          0
# 79591    65.00                            0                          0
# 118344  140.00                            0                          2
# 71919   112.67                            0                          0
# 94677   147.90                            0                          1
#
#        reservation_status reservation_status_date  courtesy arrival_date
# 32015           Check-Out              2017-01-15     False   2017-01-14
# 79591           Check-Out              2015-10-28     False   2015-10-29
# 118344          Check-Out              2016-08-13     False   2016-08-13
# 71919            Canceled              2017-07-03     False   2017-07-15
# 94677           Check-Out              2016-08-08     False   2016-07-29

# %%
df["hotel"].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
# Primer conjunto de datos basado en la fecha de status de reserva y el hotel
cancelada_status = df[(df["is_canceled"] == True) & (df["hotel"] == "Resort Hotel")].groupby([df["reservation_status_date"].dt.year, df["reservation_status_date"].dt.month])["is_canceled"].count()
no_cancelada_status = df[(df["is_canceled"] == False) & (df["hotel"] == "Resort Hotel")].groupby([df["reservation_status_date"].dt.year, df["reservation_status_date"].dt.month])["is_canceled"].count()

etiquetas_x_status = [f'{año}-{mes}' for año, mes in cancelada_status.index]
posiciones_x_status = list(range(len(etiquetas_x_status)))

plt.figure(figsize=(20, 6))

# Trazar la línea para is_canceled == True (status de reserva)
cancelada_status.plot(kind='line', marker='o', linestyle='-', color='red', linewidth=3, label='Canceladas')
# Trazar la línea para is_canceled == False (status de reserva)
no_cancelada_status.plot(kind='line', marker='s', linestyle='-', color='green', linewidth=3, label='No canceladas')

plt.title('Evolución de las reservas por Año-mes por fecha de status de la reserva - Hotel:Resort Hotel')
plt.xlabel('Año-Mes')
plt.ylabel('Número de reservas')

plt.xticks(posiciones_x_status, etiquetas_x_status, color="blue", fontsize=10, rotation=45)

plt.legend()

# Segundo conjunto de datos basado en la fecha de llegada y el hotel
cancelada_llegada = df[(df["is_canceled"] == True) & (df["hotel"] == "Resort Hotel")].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()
no_cancelada_llegada = df[(df["is_canceled"] == False) & (df["hotel"] == "Resort Hotel")].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()

etiquetas_x_llegada = [f'{año}-{mes}' for año, mes in cancelada_llegada.index]
posiciones_x_llegada = list(range(len(etiquetas_x_llegada)))

plt.figure(figsize=(20, 6))

# Trazar la línea para is_canceled == True (fecha de llegada)
cancelada_llegada.plot(kind='line', marker='o', linestyle='-', color='red', linewidth=3, label='Canceladas')
# Trazar la línea para is_canceled == False (fecha de llegada)
no_cancelada_llegada.plot(kind='line', marker='s', linestyle='-', color='green', linewidth=3, label='No canceladas')

plt.title('Evolución de las reservas por Año-mes por fecha de llegada - Hotel: Resort Hotel')
plt.xlabel('Año-Mes')
plt.ylabel('Número de reservas')

plt.xticks(posiciones_x_llegada, etiquetas_x_llegada, color="blue", fontsize=10, rotation=45)

plt.legend()

plt.tight_layout()
plt.show()

# %%
# Primer conjunto de datos basado en la fecha de status de reserva y el hotel
cancelada_status = df[(df["is_canceled"] == True) & (df["hotel"] == "City Hotel")].groupby([df["reservation_status_date"].dt.year, df["reservation_status_date"].dt.month])["is_canceled"].count()
no_cancelada_status = df[(df["is_canceled"] == False) & (df["hotel"] == "City Hotel")].groupby([df["reservation_status_date"].dt.year, df["reservation_status_date"].dt.month])["is_canceled"].count()

etiquetas_x_status = [f'{año}-{mes}' for año, mes in cancelada_status.index]
posiciones_x_status = list(range(len(etiquetas_x_status)))

plt.figure(figsize=(20, 6))

# Trazar la línea para is_canceled == True (status de reserva)
cancelada_status.plot(kind='line', marker='o', linestyle='-', color='red', linewidth=3, label='Canceladas')
# Trazar la línea para is_canceled == False (status de reserva)
no_cancelada_status.plot(kind='line', marker='s', linestyle='-', color='green', linewidth=3, label='No canceladas')

plt.title('Evolución de las reservas por Año-mes por fecha de status de la reserva - Hotel: City Hotel')
plt.xlabel('Año-Mes')
plt.ylabel('Número de reservas')

plt.xticks(posiciones_x_status, etiquetas_x_status, color="blue", fontsize=10, rotation=45)

plt.legend()

# Segundo conjunto de datos basado en la fecha de llegada y el hotel
cancelada_llegada = df[(df["is_canceled"] == True) & (df["hotel"] == "City Hotel")].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()
no_cancelada_llegada = df[(df["is_canceled"] == False) & (df["hotel"] == "City Hotel")].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()

etiquetas_x_llegada = [f'{año}-{mes}' for año, mes in cancelada_llegada.index]
posiciones_x_llegada = list(range(len(etiquetas_x_llegada)))

plt.figure(figsize=(20, 6))

# Trazar la línea para is_canceled == True (fecha de llegada)
cancelada_llegada.plot(kind='line', marker='o', linestyle='-', color='red', linewidth=3, label='Canceladas')
# Trazar la línea para is_canceled == False (fecha de llegada)
no_cancelada_llegada.plot(kind='line', marker='s', linestyle='-', color='green', linewidth=3, label='No canceladas')

plt.title('Evolución de las reservas por Año-mes por fecha de llegada - Hotel: City Hotel')
plt.xlabel('Año-Mes')
plt.ylabel('Número de reservas')

plt.xticks(posiciones_x_llegada, etiquetas_x_llegada, color="blue", fontsize=10, rotation=45)

plt.legend()

plt.tight_layout()
plt.show()

# %%
cancelada_llegada = df[(df["is_canceled"] == True) & (df["hotel"] == "City Hotel") & (df["arrival_date"].dt.year == 2016) & (df["arrival_date"].dt.month == 4)].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_255/3924375986.py in <module>
# ----> 1 cancelada_llegada = df[(df["is_canceled"] == True) & (df["hotel"] == "City Hotel") & (df["arrival_date"].dt.year == 2016) & (df["arrival_date"].dt.month == 4)].groupby([df["arrival_date"].dt.year, df["arrival_date"].dt.month])["is_canceled"].count()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     504             return PeriodProperties(data, orig)
#     505
# --> 506         raise AttributeError("Can only use .dt accessor with datetimelike values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %% [markdown]
# - El hote con más volatilidad en la cancelación es el City Hotel. Aunque el hotel Resort ha experimentado disminución en sus reservas en los últimos tiempos

# %%
df.sample(5)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_week_number  \
# 75251  City Hotel         True        297                        33
# 98232  City Hotel        False          1                        39
# 41367  City Hotel        False         40                        33
# 64911  City Hotel         True          8                        12
# 89240  City Hotel        False          6                        28
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 75251                        1                     1       2         0
# 98232                        1                     3       2         0
# 41367                        2                     2       2         0
# 64911                        1                     3      53         0
# 89240                        1                     2       2         0
#
#        babies meal    country market_segment distribution_channel  \
# 75251       0   BB   Portugal      Undefined                TA/TO
# 98232       0   BB   Portugal  Offline TA/TO                TA/TO
# 41367       0   BB      Spain         Groups                TA/TO
# 64911       0   SC  Undefined      Undefined                TA/TO
# 89240       0   BB  Argentina      Online TA                TA/TO
#
#        is_repeated_guest  previous_cancellations  \
# 75251              False                       1
# 98232              False                       0
# 41367              False                       0
# 64911              False                       0
# 89240              False                       0
#
#        previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 75251                               0                  A                  A
# 98232                               0          Undefined                  A
# 41367                               0                  A                  A
# 64911                               0                  A                  A
# 89240                               0                  A                  A
#
#        booking_changes  agent  days_in_waiting_list    customer_type     adr  \
# 75251                0    1.0                     0  Transient-Party   62.00
# 98232                0  315.0                     0  Transient-Party  176.00
# 41367                0    1.0                     0  Transient-Party   62.00
# 64911                0    9.0                     0        Transient   83.30
# 89240                0    9.0                     0        Transient  121.67
#
#        required_car_parking_spaces  total_of_special_requests  \
# 75251                            0                          0
# 98232                            0                          0
# 41367                            0                          0
# 64911                            0                          0
# 89240                            0                          1
#
#       reservation_status reservation_status_date  courtesy arrival_date
# 75251           Canceled              2015-07-02     False   2015-08-10
# 98232          Check-Out              2016-09-26     False   2016-09-22
# 41367          Check-Out              2024-09-28     False   2024-08-15
# 64911           Canceled              2017-03-12     False   2017-03-20
# 89240          Check-Out              2016-05-19     False   2016-05-16

# %%
df["country"].unique()
# Out:
# array(['Portugal', 'Undefined', 'United Kingdom', 'United States',
#        'Spain', 'Ireland', 'France', 'Romania', 'Norway', 'Oman',
#        'Argentina', 'Germany', 'Switzerland', 'Greece', 'Netherlands',
#        'Denmark', 'Russia', 'Poland', 'Australia', 'Estonia',
#        'Czech Republic', 'Brazil', 'Belgium', 'China', 'Sweden',
#        'Finland', 'Mozambique', 'Slovenia', 'Morocco', 'Italy', 'Ukraine',
#        'San Marino', 'Latvia', 'Puerto Rico', 'Chile', 'Lithuania',
#        'Luxembourg', 'Austria', 'Turkey', 'Mexico', 'South Africa',
#        'Angola', 'Israel', 'India', 'Cayman Islands', 'Zambia',
#        'Cape Verde', 'Zimbabwe', 'Algeria', 'South Korea', 'Hungary',
#        'United Arab Emirates', 'Tunisia', 'Jamaica', 'Albania', 'Croatia',
#        'Hong Kong', 'Andorra', 'Gibraltar', 'Uruguay', 'Belarus',
#        'Jersey', 'Cyprus', 'Maldives', 'Fiji', 'Kazakhstan', 'Pakistan',
#        'Indonesia', 'Lebanon', 'Philippines', 'Colombia', 'Senegal',
#        'Georgia', 'Azerbaijan', 'Bahrain', 'New Zealand', 'Thailand',
#        'Dominican Republic', 'Malaysia', 'Venezuela', 'Armenia',
#        'Sri Lanka', 'Cuba', 'Cameroon', 'Iran', 'Nigeria', 'Comoros',
#        'Bulgaria', "Côte d'Ivoire", 'Serbia', 'Jordan', 'Syria',
#        'Burundi', 'Singapore', 'Kuwait', 'Palau', 'Qatar', 'Slovakia',
#        'Suriname', 'Malta', 'Malawi', 'Madagascar', 'Iceland', 'Japan',
#        'Central African Republic', 'Togo', 'Taiwan', 'Djibouti',
#        'Vietnam', 'Peru', 'Egypt', 'Saudi Arabia',
#        'Saint Kitts and Nevis', 'Ethiopia', 'Ecuador', 'Iraq', 'Cambodia',
#        'Monaco', 'Bangladesh', 'Tajikistan', 'Nicaragua', 'Guernsey',
#        'Benin', 'British Virgin Islands', 'Costa Rica', 'Tanzania',
#        'Gabon', 'North Macedonia', 'Bosnia and Herzegovina', 'East Timor',
#        'Guadeloupe', 'Liechtenstein', 'Guinea-Bissau', 'Macau',
#        'Isle of Man', 'United States Minor Outlying Islands', 'Mayotte',
#        'Ghana', 'Faroe Islands', 'Myanmar', 'Panama', 'Mauritius',
#        'Libya', 'Namibia', 'Bolivia', 'Paraguay', 'Barbados', 'Aruba',
#        'Anguilla', 'Dominica', 'Uganda', 'Montenegro', 'Guatemala',
#        'American Samoa', 'Kenya', 'New Caledonia',
#        'São Tomé and Príncipe', 'Kiribati', 'Sudan',
#        'French Southern Territories', 'Sierra Leone', 'El Salvador',
#        'Laos'], dtype=object)

# %%
paises_a_continentes = {
    'Portugal': 'Europa',
    'Undefined': 'Desconocido',
    'United Kingdom': 'Europa',
    'United States': 'América del Norte',
    'Spain': 'Europa',
    'Ireland': 'Europa',
    'France': 'Europa',
    'Romania': 'Europa',
    'Norway': 'Europa',
    'Oman': 'Asia',
    'Argentina': 'América del Sur',
    'Germany': 'Europa',
    'Switzerland': 'Europa',
    'Greece': 'Europa',
    'Netherlands': 'Europa',
    'Denmark': 'Europa',
    'Russia': 'Europa',
    'Poland': 'Europa',
    'Australia': 'Oceanía',
    'Estonia': 'Europa',
    'Czech Republic': 'Europa',
    'Brazil': 'América del Sur',
    'Belgium': 'Europa',
    'China': 'Asia',
    'Sweden': 'Europa',
    'Finland': 'Europa',
    'Mozambique': 'África',
    'Slovenia': 'Europa',
    'Morocco': 'África',
    'Italy': 'Europa',
    'Ukraine': 'Europa',
    'San Marino': 'Europa',
    'Latvia': 'Europa',
    'Puerto Rico': 'América del Norte',
    'Chile': 'América del Sur',
    'Lithuania': 'Europa',
    'Luxembourg': 'Europa',
    'Austria': 'Europa',
    'Turkey': 'Asia',
    'Mexico': 'América del Norte',
    'South Africa': 'África',
    'Angola': 'África',
    'Israel': 'Asia',
    'India': 'Asia',
    'Cayman Islands': 'América del Norte',
    'Zambia': 'África',
    'Cape Verde': 'África',
    'Zimbabwe': 'África',
    'Algeria': 'África',
    'South Korea': 'Asia',
    'Hungary': 'Europa',
    'United Arab Emirates': 'Asia',
    'Tunisia': 'África',
    'Jamaica': 'América del Norte',
    'Albania': 'Europa',
    'Croatia': 'Europa',
    'Hong Kong': 'Asia',
    'Andorra': 'Europa',
    'Gibraltar': 'Europa',
    'Uruguay': 'América del Sur',
    'Belarus': 'Europa',
    'Jersey': 'Europa',
    'Cyprus': 'Europa',
    'Maldives': 'Asia',
    'Fiji': 'Oceanía',
    'Kazakhstan': 'Asia',
    'Pakistan': 'Asia',
    'Indonesia': 'Asia',
    'Lebanon': 'Asia',
    'Philippines': 'Asia',
    'Colombia': 'América del Sur',
    'Senegal': 'África',
    'Georgia': 'Asia',
    'Azerbaijan': 'Asia',
    'Bahrain': 'Asia',
    'New Zealand': 'Oceanía',
    'Thailand': 'Asia',
    'Dominican Republic': 'América del Norte',
    'Malaysia': 'Asia',
    'Venezuela': 'América del Sur',
    'Armenia': 'Asia',
    'Sri Lanka': 'Asia',
    'Cuba': 'América del Norte',
    'Cameroon': 'África',
    'Iran': 'Asia',
    'Nigeria': 'África',
    'Comoros': 'África',
    'Bulgaria': 'Europa',
    "Côte d'Ivoire": 'África',
    'Serbia': 'Europa',
    'Jordan': 'Asia',
    'Syria': 'Asia',
    'Burundi': 'África',
    'Singapore': 'Asia',
    'Kuwait': 'Asia',
    'Palau': 'Oceanía',
    'Qatar': 'Asia',
    'Slovakia': 'Europa',
    'Suriname': 'América del Sur',
    'Malta': 'Europa',
    'Malawi': 'África',
    'Madagascar': 'África',
    'Iceland': 'Europa',
    'Japan': 'Asia',
    'Central African Republic': 'África',
    'Togo': 'África',
    'Taiwan': 'Asia',
    'Djibouti': 'África',
    'Vietnam': 'Asia',
    'Peru': 'América del Sur',
    'Egypt': 'África',
    'Saudi Arabia': 'Asia',
    'Saint Kitts and Nevis': 'América del Norte',
    'Ethiopia': 'África',
    'Ecuador': 'América del Sur',
    'Iraq': 'Asia',
    'Cambodia': 'Asia',
    'Monaco': 'Europa',
    'Bangladesh': 'Asia',
    'Tajikistan': 'Asia',
    'Nicaragua': 'América del Norte',
    'Guernsey': 'Europa',
    'Benin': 'África',
    'British Virgin Islands': 'América del Norte',
    'Costa Rica': 'América del Norte',
    'Tanzania': 'África',
    'Gabon': 'África',
    'North Macedonia': 'Europa',
    'Bosnia and Herzegovina': 'Europa',
    'East Timor': 'Oceanía',
    'Guadeloupe': 'América del Norte',
    'Liechtenstein': 'Europa',
    'Guinea-Bissau': 'África',
    'Macau': 'Asia',
    'Isle of Man': 'Europa',
    'United States Minor Outlying Islands': 'Oceanía',
    'Mayotte': 'África',
    'Ghana': 'África',
    'Faroe Islands': 'Europa',
    'Myanmar': 'Asia',
    'Panama': 'América del Norte',
    'Mauritius': 'África',
    'Libya': 'África',
    'Namibia': 'África',
    'Bolivia': 'América del Sur',
    'Paraguay': 'América del Sur',
    'Barbados': 'América del Norte',
    'Aruba': 'América del Norte',
    'Anguilla': 'América del Norte',
    'Dominica': 'América del Norte',
    'Uganda': 'África',
    'Montenegro': 'Europa',
    'Guatemala': 'América del Norte',
    'American Samoa': 'Oceanía',
    'Kenya': 'África',
    'New Caledonia': 'Oceanía',
    'São Tomé and Príncipe': 'África',
    'Kiribati': 'Oceanía',
    'Sudan': 'África',
    'French Southern Territories': 'Antártida',
    'Sierra Leone': 'África',
    'El Salvador': 'América del Norte',
    'Laos': 'Asia'
}

# %%
df['continente'] = df['country'].map(paises_a_continentes)

# %%
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_week_number  \
# 0  Resort Hotel        False        342                        27
# 1  Resort Hotel        False        737                        27
# 2  Resort Hotel        False          7                        27
# 3  Resort Hotel        False         13                        27
# 4  Resort Hotel        False         14                        28
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2         0       0
# 1                        0                     0       2         0       0
# 2                        0                     1       1         0       0
# 3                        0                     1       1         0       0
# 4                        0                     2       2         0       0
#
#   meal         country market_segment distribution_channel  is_repeated_guest  \
# 0   BB        Portugal      Undefined               Direct              False
# 1   BB       Undefined      Undefined               Direct              False
# 2   BB  United Kingdom      Undefined               Direct              False
# 3   BB  United Kingdom      Corporate            Corporate              False
# 4   BB       Undefined      Online TA                TA/TO              False
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  C
# 1                       0                               0          Undefined
# 2                       0                               0                  A
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#   assigned_room_type  booking_changes      agent  days_in_waiting_list  \
# 0                  C                3  Undefined                     0
# 1                  C                4  Undefined                     0
# 2                  C                0  Undefined                     0
# 3                  A                0      304.0                     0
# 4                  A                0      240.0                     0
#
#   customer_type   adr  required_car_parking_spaces  total_of_special_requests  \
# 0     Transient   0.0                            0                          0
# 1     Transient   0.0                            0                          0
# 2     Transient  75.0                            0                          0
# 3     Transient  75.0                            0                          0
# 4     Transient  98.0                            0                          1
#
#   reservation_status reservation_status_date  courtesy arrival_date  \
# 0          Check-Out              2015-07-01      True   2015-07-01
# 1          Check-Out              2015-07-01      True   2015-07-01
# 2          Check-Out              2015-07-02     False   2015-07-01
# 3          Check-Out              2015-07-02     False   2015-07-01
# 4          Check-Out              2015-07-03     False   2015-07-01
#
#     continente
# 0       Europa
# 1  Desconocido
# 2       Europa
# 3       Europa
# 4  Desconocido

# %%
df2 = df[df["is_canceled"] == False]

# %%
country = df["country"].unique()

for pais in country:
    cancelada = df[(df["hotel"] == "City Hotel") & (df["country"] == pais) & (df["is_canceled"] == True)]["is_canceled"].count()
    no_cancelada = df[(df["hotel"] == "City Hotel") & (df["country"] == pais) & (df["is_canceled"] != True)]["is_canceled"].count()

    print(f'Para el país {pais} en el hotel "City Hotel" el total de cancelaciones fue {cancelada} y el total de reservas {no_cancelada}')
    print("------------------------------------------------------------------------------------------------------------------------")
# Out:
# Para el país Portugal en el hotel "City Hotel" el total de cancelaciones fue 10914 y el total de reservas 5906
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Undefined en el hotel "City Hotel" el total de cancelaciones fue 14625 y el total de reservas 20328
# ------------------------------------------------------------------------------------------------------------------------
# Para el país United Kingdom en el hotel "City Hotel" el total de cancelaciones fue 881 y el total de reservas 2053
# ------------------------------------------------------------------------------------------------------------------------
# Para el país United States en el hotel "City Hotel" el total de cancelaciones fue 245 y el total de reservas 650
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Spain en el hotel "City Hotel" el total de cancelaciones fue 709 y el total de reservas 1804
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Ireland en el hotel "City Hotel" el total de cancelaciones fue 218 y el total de reservas 430
# ------------------------------------------------------------------------------------------------------------------------
# Para el país France en el hotel "City Hotel" el total de cancelaciones fue 946 y el total de reservas 3898
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Romania en el hotel "City Hotel" el total de cancelaciones fue 55 y el total de reservas 116
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Norway en el hotel "City Hotel" el total de cancelaciones fue 88 y el total de reservas 193
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Oman en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Argentina en el hotel "City Hotel" el total de cancelaciones fue 21 y el total de reservas 58
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Germany en el hotel "City Hotel" el total de cancelaciones fue 569 y el total de reservas 2732
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Switzerland en el hotel "City Hotel" el total de cancelaciones fue 180 y el total de reservas 545
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Greece en el hotel "City Hotel" el total de cancelaciones fue 19 y el total de reservas 53
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Netherlands en el hotel "City Hotel" el total de cancelaciones fue 182 y el total de reservas 685
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Denmark en el hotel "City Hotel" el total de cancelaciones fue 48 y el total de reservas 141
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Russia en el hotel "City Hotel" el total de cancelaciones fue 87 y el total de reservas 138
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Poland en el hotel "City Hotel" el total de cancelaciones fue 109 y el total de reservas 224
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Australia en el hotel "City Hotel" el total de cancelaciones fue 44 y el total de reservas 140
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Estonia en el hotel "City Hotel" el total de cancelaciones fue 8 y el total de reservas 20
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Czech Republic en el hotel "City Hotel" el total de cancelaciones fue 17 y el total de reservas 55
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Brazil en el hotel "City Hotel" el total de cancelaciones fue 380 y el total de reservas 565
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Belgium en el hotel "City Hotel" el total de cancelaciones fue 244 y el total de reservas 811
# ------------------------------------------------------------------------------------------------------------------------
# Para el país China en el hotel "City Hotel" el total de cancelaciones fue 329 y el total de reservas 438
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Sweden en el hotel "City Hotel" el total de cancelaciones fue 82 y el total de reservas 295
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Finland en el hotel "City Hotel" el total de cancelaciones fue 26 y el total de reservas 141
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Mozambique en el hotel "City Hotel" el total de cancelaciones fue 7 y el total de reservas 25
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Slovenia en el hotel "City Hotel" el total de cancelaciones fue 10 y el total de reservas 13
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Morocco en el hotel "City Hotel" el total de cancelaciones fue 41 y el total de reservas 70
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Italy en el hotel "City Hotel" el total de cancelaciones fue 680 y el total de reservas 1128
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Ukraine en el hotel "City Hotel" el total de cancelaciones fue 11 y el total de reservas 13
# ------------------------------------------------------------------------------------------------------------------------
# Para el país San Marino en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Latvia en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 12
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Puerto Rico en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Chile en el hotel "City Hotel" el total de cancelaciones fue 9 y el total de reservas 19
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Lithuania en el hotel "City Hotel" el total de cancelaciones fue 5 y el total de reservas 20
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Luxembourg en el hotel "City Hotel" el total de cancelaciones fue 46 y el total de reservas 68
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Austria en el hotel "City Hotel" el total de cancelaciones fue 106 y el total de reservas 437
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Turkey en el hotel "City Hotel" el total de cancelaciones fue 57 y el total de reservas 72
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Mexico en el hotel "City Hotel" el total de cancelaciones fue 4 y el total de reservas 41
# ------------------------------------------------------------------------------------------------------------------------
# Para el país South Africa en el hotel "City Hotel" el total de cancelaciones fue 14 y el total de reservas 17
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Angola en el hotel "City Hotel" el total de cancelaciones fue 105 y el total de reservas 69
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Israel en el hotel "City Hotel" el total de cancelaciones fue 88 y el total de reservas 273
# ------------------------------------------------------------------------------------------------------------------------
# Para el país India en el hotel "City Hotel" el total de cancelaciones fue 20 y el total de reservas 49
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Cayman Islands en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Zambia en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Cape Verde en el hotel "City Hotel" el total de cancelaciones fue 7 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Zimbabwe en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Algeria en el hotel "City Hotel" el total de cancelaciones fue 10 y el total de reservas 39
# ------------------------------------------------------------------------------------------------------------------------
# Para el país South Korea en el hotel "City Hotel" el total de cancelaciones fue 26 y el total de reservas 40
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Hungary en el hotel "City Hotel" el total de cancelaciones fue 38 y el total de reservas 54
# ------------------------------------------------------------------------------------------------------------------------
# Para el país United Arab Emirates en el hotel "City Hotel" el total de cancelaciones fue 19 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Tunisia en el hotel "City Hotel" el total de cancelaciones fue 10 y el total de reservas 9
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Jamaica en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Albania en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Croatia en el hotel "City Hotel" el total de cancelaciones fue 15 y el total de reservas 37
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Hong Kong en el hotel "City Hotel" el total de cancelaciones fue 11 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Andorra en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Gibraltar en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Uruguay en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 10
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Belarus en el hotel "City Hotel" el total de cancelaciones fue 5 y el total de reservas 9
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Jersey en el hotel "City Hotel" el total de cancelaciones fue 4 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Cyprus en el hotel "City Hotel" el total de cancelaciones fue 5 y el total de reservas 12
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Maldives en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Fiji en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Kazakhstan en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Pakistan en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Indonesia en el hotel "City Hotel" el total de cancelaciones fue 16 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Lebanon en el hotel "City Hotel" el total de cancelaciones fue 4 y el total de reservas 11
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Philippines en el hotel "City Hotel" el total de cancelaciones fue 6 y el total de reservas 7
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Colombia en el hotel "City Hotel" el total de cancelaciones fue 10 y el total de reservas 15
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Senegal en el hotel "City Hotel" el total de cancelaciones fue 7 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Georgia en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Azerbaijan en el hotel "City Hotel" el total de cancelaciones fue 6 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Bahrain en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país New Zealand en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 24
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Thailand en el hotel "City Hotel" el total de cancelaciones fue 12 y el total de reservas 18
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Dominican Republic en el hotel "City Hotel" el total de cancelaciones fue 6 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Malaysia en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 11
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Venezuela en el hotel "City Hotel" el total de cancelaciones fue 5 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Armenia en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Sri Lanka en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Cuba en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Cameroon en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Iran en el hotel "City Hotel" el total de cancelaciones fue 16 y el total de reservas 27
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Nigeria en el hotel "City Hotel" el total de cancelaciones fue 15 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Comoros en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Bulgaria en el hotel "City Hotel" el total de cancelaciones fue 5 y el total de reservas 35
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Côte d'Ivoire en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Serbia en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 53
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Jordan en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 7
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Syria en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Burundi en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Singapore en el hotel "City Hotel" el total de cancelaciones fue 8 y el total de reservas 9
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Kuwait en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Palau en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Qatar en el hotel "City Hotel" el total de cancelaciones fue 6 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Slovakia en el hotel "City Hotel" el total de cancelaciones fue 13 y el total de reservas 16
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Suriname en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Malta en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 5
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Malawi en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Madagascar en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Iceland en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 22
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Japan en el hotel "City Hotel" el total de cancelaciones fue 14 y el total de reservas 97
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Central African Republic en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Togo en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Taiwan en el hotel "City Hotel" el total de cancelaciones fue 6 y el total de reservas 15
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Djibouti en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Vietnam en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Peru en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 14
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Egypt en el hotel "City Hotel" el total de cancelaciones fue 4 y el total de reservas 11
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Saudi Arabia en el hotel "City Hotel" el total de cancelaciones fue 18 y el total de reservas 8
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Saint Kitts and Nevis en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Ethiopia en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Ecuador en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 9
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Iraq en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 5
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Cambodia en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Monaco en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Bangladesh en el hotel "City Hotel" el total de cancelaciones fue 7 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Tajikistan en el hotel "City Hotel" el total de cancelaciones fue 6 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Nicaragua en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Guernsey en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Benin en el hotel "City Hotel" el total de cancelaciones fue 3 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país British Virgin Islands en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Costa Rica en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 8
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Tanzania en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Gabon en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país North Macedonia en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 5
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Bosnia and Herzegovina en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 8
# ------------------------------------------------------------------------------------------------------------------------
# Para el país East Timor en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Guadeloupe en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Liechtenstein en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Guinea-Bissau en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Macau en el hotel "City Hotel" el total de cancelaciones fue 5 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Isle of Man en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país United States Minor Outlying Islands en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Mayotte en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 0
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Ghana en el hotel "City Hotel" el total de cancelaciones fue 1 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Faroe Islands en el hotel "City Hotel" el total de cancelaciones fue 2 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Myanmar en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Panama en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 6
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Mauritius en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Libya en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Namibia en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Bolivia en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 4
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Paraguay en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Barbados en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 3
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Aruba en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Anguilla en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Dominica en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Uganda en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Montenegro en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Guatemala en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país American Samoa en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Kenya en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------
# Para el país New Caledonia en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país São Tomé and Príncipe en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Kiribati en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Sudan en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país French Southern Territories en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Sierra Leone en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país El Salvador en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 1
# ------------------------------------------------------------------------------------------------------------------------
# Para el país Laos en el hotel "City Hotel" el total de cancelaciones fue 0 y el total de reservas 2
# ------------------------------------------------------------------------------------------------------------------------

# %%
top_10_no_canceladas_por_pais = df[df["is_canceled"] != True].groupby("country")["is_canceled"].count().nlargest(10)
print("Top 10 de reservas no canceladas por país:")
print(top_10_no_canceladas_por_pais)
# Out:
# Top 10 de reservas no canceladas por país:
# country
# Undefined         33179
# Portugal          11458
# United Kingdom     5184
# France             4660
# Spain              3499
# Germany            3318
# Ireland            1340
# Italy              1336
# Belgium            1027
# Netherlands         939
# Name: is_canceled, dtype: int64

# %%
top_10_no_canceladas_por_pais = df[df["is_canceled"] == True].groupby("country")["is_canceled"].count().nlargest(10)
print("Top 10 de reservas canceladas por país:")
print(top_10_no_canceladas_por_pais)
# Out:
# Top 10 de reservas canceladas por país:
# country
# Undefined         19546
# Portugal          14935
# United Kingdom     1370
# Spain              1192
# France             1069
# Italy               727
# Germany             644
# Ireland             453
# Brazil              429
# China               389
# Name: is_canceled, dtype: int64

# %%
top_10_no_canceladas_por_pais = df[df["is_canceled"] != True].groupby("country")["is_canceled"].count().nlargest(10)
paises_top_10 = top_10_no_canceladas_por_pais.index.tolist()

df_top_10_paises = df[df['country'].isin(paises_top_10)]


media = df_top_10_paises.groupby([
    df_top_10_paises['arrival_date'].dt.year.rename("year"),
    df_top_10_paises['arrival_date'].dt.month.rename("month"),
    df_top_10_paises['country'],
    df_top_10_paises['hotel'],
    df_top_10_paises['continente'],
    df_top_10_paises['is_canceled']  # Suponiendo que 'is_canceled' es una columna en tu DataFrame
    ])['adr'].mean()

# %%
media
# Out:
# year  month  country    hotel         continente   is_canceled
# 2014  7      Portugal   City Hotel    Europa       True            62.8
#              Undefined  City Hotel    Desconocido  True            62.8
#       8      Portugal   City Hotel    Europa       True            62.8
#              Undefined  City Hotel    Desconocido  True            62.8
#       9      Portugal   City Hotel    Europa       True            62.8
#                                                                   ...
# 2027  4      Undefined  City Hotel    Desconocido  False          100.8
# 2029  10     Portugal   Resort Hotel  Europa       True            38.0
# 2030  4      Undefined  City Hotel    Desconocido  False          108.0
#       8      Undefined  Resort Hotel  Desconocido  True           222.0
#       12     Portugal   Resort Hotel  Europa       True            72.0
# Name: adr, Length: 1004, dtype: float64

# %%
df_media = media.reset_index()

# %%
df_media
# Out:
#       year  month    country         hotel   continente  is_canceled    adr
# 0     2014      7   Portugal    City Hotel       Europa         True   62.8
# 1     2014      7  Undefined    City Hotel  Desconocido         True   62.8
# 2     2014      8   Portugal    City Hotel       Europa         True   62.8
# 3     2014      8  Undefined    City Hotel  Desconocido         True   62.8
# 4     2014      9   Portugal    City Hotel       Europa         True   62.8
# ...    ...    ...        ...           ...          ...          ...    ...
# 999   2027      4  Undefined    City Hotel  Desconocido        False  100.8
# 1000  2029     10   Portugal  Resort Hotel       Europa         True   38.0
# 1001  2030      4  Undefined    City Hotel  Desconocido        False  108.0
# 1002  2030      8  Undefined  Resort Hotel  Desconocido         True  222.0
# 1003  2030     12   Portugal  Resort Hotel       Europa         True   72.0
#
# [1004 rows x 7 columns]

# %%
df_canceled_false = df_media[(df_media['hotel'] == 'City Hotel') & (df_media['is_canceled'] == False)]

# %%
df_canceled_false
# Out:
#       year  month         country       hotel   continente  is_canceled  \
# 38    2015      7          France  City Hotel       Europa        False
# 40    2015      7         Germany  City Hotel       Europa        False
# 43    2015      7           Italy  City Hotel       Europa        False
# 47    2015      7        Portugal  City Hotel       Europa        False
# 51    2015      7           Spain  City Hotel       Europa        False
# ...    ...    ...             ...         ...          ...          ...
# 991   2017     12  United Kingdom  City Hotel       Europa        False
# 994   2024      8           Spain  City Hotel       Europa        False
# 995   2024     10       Undefined  City Hotel  Desconocido        False
# 999   2027      4       Undefined  City Hotel  Desconocido        False
# 1001  2030      4       Undefined  City Hotel  Desconocido        False
#
#              adr
# 38     76.500000
# 40     61.980000
# 43     75.437500
# 47     75.394464
# 51     49.200000
# ...          ...
# 991    53.470000
# 994    62.000000
# 995    80.750000
# 999   100.800000
# 1001  108.000000
#
# [268 rows x 7 columns]

# %%
df_canceled_false.sort_values(by= "adr",ascending=False)
# Out:
#      year  month         country       hotel continente  is_canceled  \
# 979  2017     12         Belgium  City Hotel     Europa        False
# 987  2017     12           Spain  City Hotel     Europa        False
# 967  2017      8           Spain  City Hotel     Europa        False
# 943  2017      8          France  City Hotel     Europa        False
# 840  2017      5     Netherlands  City Hotel     Europa        False
# ..    ...    ...             ...         ...        ...          ...
# 57   2015      7  United Kingdom  City Hotel     Europa        False
# 40   2015      7         Germany  City Hotel     Europa        False
# 991  2017     12  United Kingdom  City Hotel     Europa        False
# 51   2015      7           Spain  City Hotel     Europa        False
# 177  2015     12         Germany  City Hotel     Europa        False
#
#             adr
# 979  271.290000
# 987  174.540000
# 967  153.238438
# 943  150.051813
# 840  147.047895
# ..          ...
# 57    61.980000
# 40    61.980000
# 991   53.470000
# 51    49.200000
# 177   29.408571
#
# [268 rows x 7 columns]

# %%
# Dividir la lista de países en dos partes
mitad = len(paises) // 2
paises_primera_fila = paises[:mitad]
paises_segunda_fila = paises[mitad:]

# Crear subgráficos para la primera fila de países
fig, axes = plt.subplots(ncols=len(paises_primera_fila), figsize=(6*len(paises_primera_fila), 8), sharey=True)

# Iterar sobre cada país en la primera fila y crear un gráfico de líneas
for i, pais in enumerate(paises_primera_fila):
    # Filtrar los datos para el país actual
    datos_pais = costo_medio_por_pais.loc[pais]
    # Crear un gráfico de líneas para el país actual
    datos_pais.plot(ax=axes[i], marker='o', linestyle='-')
    axes[i].set_title(f'Costo Medio del Hotel en {pais}')
    axes[i].set_xlabel('Fecha')
    axes[i].set_ylabel('Costo Medio del Hotel')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar los gráficos de la primera fila
plt.show()

# Crear subgráficos para la segunda fila de países
fig, axes = plt.subplots(ncols=len(paises_segunda_fila), figsize=(6*len(paises_segunda_fila), 8), sharey=True)

# Iterar sobre cada país en la segunda fila y crear un gráfico de líneas
for i, pais in enumerate(paises_segunda_fila):
    # Filtrar los datos para el país actual
    datos_pais = costo_medio_por_pais.loc[pais]
    # Crear un gráfico de líneas para el país actual
    datos_pais.plot(ax=axes[i], marker='o', linestyle='-')
    axes[i].set_title(f'Costo Medio del Hotel en {pais}')
    axes[i].set_xlabel('Fecha')
    axes[i].set_ylabel('Costo Medio del Hotel')

# Ajustar el espaciado entre subgráficos
plt.tight_layout()

# Mostrar los gráficos de la segunda fila
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16837/3472154167.py in <module>
#       1 # Dividir la lista de países en dos partes
# ----> 2 mitad = len(paises) // 2
#       3 paises_primera_fila = paises[:mitad]
#       4 paises_segunda_fila = paises[mitad:]
#       5
#
# NameError: name 'paises' is not defined
